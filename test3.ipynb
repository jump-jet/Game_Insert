# %%
import pandas as pd
import csv
from datetime import datetime

now = datetime.now()
current_time = now.strftime("%Y-%m-%d %H:%M:%S")

pd.options.display.max_rows = 999

df = pd.read_csv('data.csv')
df = pd.DataFrame(df)

df_provider = pd.read_csv('siam123.csv')
df_provider = pd.DataFrame(df_provider)

df_lang = pd.read_csv('lang_code.csv')
df_lang = pd.DataFrame(df_lang)

table = '`game_list`'
type_ = '1'
lang_code = 'G00100'
status = '1'
a = "` ( `"



with open("game.txt","w") as f:
     for row in df.itertuples():
          provider_name = row.provider
          print(provider_name)
          result = df_provider.loc[df_provider['display'] == provider_name,'id']
          
          for result_id in result:   
               provider_id = result_id
               value = f'INSERT INTO {table} (`id`,`name`,`code`,`type`,`provider_id`,`provider_name`,`lang_code`,`status`,`created`,`img`) VALUES (NULL,{repr(row.name)},{repr(row.code)},{repr(type_)},{repr(provider_id)},{repr(row.provider)},{repr(lang_code)},{repr(status)},{repr(current_time)},{repr(row.img)}); \n'
               f.write(value)
 












# abb = df_provider.id
# for all_provider in abb:
#      print(all_provider)

# provider_id = ["PG","PG","QTech","PlayTech-Slot"]
# if df_provider.loc[df_provider['display']] == df.loc[df['provider']]:
    
# for row in df.itertuples(): 
     
#      abc = row.provider
# provider_id = abc



# for i,provider in enumerate(df_provider["display"]):
#      if provider == input_provider:
#         provider_id = provider
#         print(input_provider)

# for row in df.itertuples(): 
#      provider_id = row.provider
#      result = df_provider.loc[df_provider['display'] == provider_id,'id']
#      for result_id in result:
#           print(result_id)

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df = pd.DataFrame(df)

df_provider = pd.read_csv('siam123.csv')
df_provider = pd.DataFrame(df_provider)

df_lang = pd.read_csv('lang_code.csv')
df_lang = pd.DataFrame(df_lang)



for row in df.itertuples():
    provider_name = row.provider
    
    lang = df_lang.loc[df_lang['provider_name'] == provider_name,'provider_name']
    for lang_code in lang: 
        # print(lang_code)
        # print(lang.to_string())
        # print(list(lang))
# Out:
# ['PG']
# ['PG']
# ['QTech']
# ['PlayTech-SLOT']
# ['KA']
# ['KA']
# ['Joker']
# ['YGG-SBO']

# %%
import pandas as pd
from datetime import datetime

now = datetime.now()
current_time = now.strftime("%Y-%m-%d %H:%M:%S")

pd.options.display.max_rows = 999

df = pd.read_csv('data.csv')
df = pd.DataFrame(df)

table = '`game_list`'
type_ = '1'
provider_name = 'QS'
lang_code = 'G00100'
status = '1'
a = "` ( `"

df_provider = pd.read_csv('siam123.csv')
df_provider = pd.DataFrame(df_provider)

input_provider = 'QTech'

for i,provider in enumerate(df_provider["display"]):
     if provider == input_provider:
        provider_id = provider
        
result = df_provider.loc[df_provider['display'] == provider_id,'id']
for result_id in result:
     provider_id = result_id
#     print(result_id)


with open("game.txt","w") as f:
   
     for row in df.itertuples():
      value = f'INSERT INTO {table} (`id`,`name`,`code`,`type`,`provider_id`,`provider_name`,`lang_code`,`status`,`created`,`img`) VALUES (NULL,{repr(row.name)},{repr(row.code)},{repr(type_)},{repr(provider_id)},{repr(provider_name)},{repr(lang_code)},{repr(status)},{repr(current_time)},{repr(row.img)}); \n'
      f.write(value)

# %%
import pandas as pd


pd.options.display.max_rows = 999

df_provider = pd.read_csv('siam123.csv')
df_provider = pd.DataFrame(df_provider)

input_provider = 'QTech'

for i,provider in enumerate(df_provider["display"]):
     if provider == input_provider:
        provider_id = provider
        
result = df_provider.loc[df_provider['display'] == provider_id,'id']
for result_id in result:
     provider_id = result_id
     print(provider_id)
